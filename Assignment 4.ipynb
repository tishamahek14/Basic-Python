# %%
#Q2.Case 1
alphabet=input("Enter the alphabet :")
if alphabet in ('a','e','i','o','u') :
       print("Vowel")
else :
       print("Consonant")
# Out:
# Enter the alphabet : a
# Vowel

# %%
#Q2.Case 2
alphabet=input("Enter the alphabet :")
if alphabet in ('a','e','i','o','u') :
       print("Vowel")
else :
       print("Consonant")
# Out:
# Enter the alphabet : z
# Consonant

# %%
#Q1.
a=input("Enter the number: ")
b=(a)
if a=="" :
    print("Empty String")
else :
    print("Not Empty")
# Out:
# Enter the number:  "
# Not Empty

# %%
#Q3.Case 1.
a=float(input("Enter the number : "))
b=float(input("Enter the number : "))
c=float(input("Enter the number : "))
Discriminant=(b*b-4*a*c)
if Discriminant>0 :
    print("Two distinct real roots")
elif Discriminant<0 :
    print("Two complex real root")
else :
    print("Exactly one real root")
# Out:
# Enter the number :  1
# Enter the number :  -3
# Enter the number :  2
# Two distinct real roots

# %%
#Q3. Case2.
a=float(input("Enter the number : "))
b=float(input("Enter the number : "))
c=float(input("Enter the number : "))
Discriminant=(b*b-4*a*c)
if Discriminant>0 :
    print("Two distinct real roots")
elif Discriminant<0 :
    print("Two complex real root")
else :
    print("Exactly one real root")
# Out:
# Enter the number :  1
# Enter the number :  2
# Enter the number :  1
# Exactly one real root

# %%
#Q4.Case 1.
a=int(input("Enter the number"))
if a%3==0 and a%2==0 :
        print("Even and divisible by 3")
elif a%2==0 :
        print("Even but not divisible by 3")
else :
        print("Odd")
# Out:
# Enter the number 12
# Even and divisible by 3

# %%
#Q4.Case 2.
a=int(input("Enter the number"))
if a%3==0 and a%2==0 :
        print("Even and divisible by 3")
elif a%2==0 :
        print("Even but not divisible by 3")
else :
        print("Odd")
# Out:
# Enter the number 7
# Odd

# %%
#Q5.Case 1.
a=input("Enter the Username :")
b=int(input("Enter the Password :"))
if a== "ADMIN" and b== 1234 :
        print("Login Successful")
else :
        print("Invalid")
# Out:
# Enter the Username : ADMIN
# Enter the Password : 1234
# Login Successful

# %%
#Q5.Case 2.
a=input("Enter the Username :")
b=int(input("Enter the Password :"))
if a== "ADMIN" and b== 1234 :
        print("Login Successful")
else :
        print("Invalid")
# Out:
# Enter the Username : ADMIN
# Enter the Password : 0000
# Invalid

# %%
#Q7.Case 1.
marks=int(input("Enter the Marks :"))
if marks<=100 and marks>=90 :
    print("Grade A")
elif marks>=80 and marks<=89 :
    print("Grade B")
elif marks>=70 and marks<=79 :
    print("Grade C")
elif marks>=60 and marks<=69 :
    print("Grade D")
else :
    if marks in range(0,100):
        print("Grade E")
    else :
        print("Invalid Marks")
# Out:
# Enter the Marks : 95
# Grade A

# %%
#Q7.Case 2.
marks=int(input("Enter the Marks :"))
if marks<=100 and marks>=90 :
    print("Grade A")
elif marks>=80 and marks<=89 :
    print("Grade B")
elif marks>=70 and marks<=79 :
    print("Grade C")
elif marks>=60 and marks<=69 :
    print("Grade D")
else :
    if marks in range(0,100):
        print("Grade E")
    else :
        print("Invalid Marks")
# Out:
# Enter the Marks : 40
# Grade E

# %%
#Q8.Case1.
a=input("Enter the Username :")
b=input("Enter the Password :")
c=input("Enter your Role(Admin/Manager/User):")
if a== "user1" and b== "pass1" :
        if c== "Admin" :
            print("Admin Dashboard")
        elif c== "Manager" :
            print("Team View")
        elif c== "User" : 
            print("Profile Page")
        else :
            print("Access Denied")
else :
    print("Invalid Credentials")
# Out:
# Enter the Username : user1
# Enter the Password : pass1
# Enter your Role(Admin/Manager/User): Agent
# Access Denied

# %%
#Q8.Case2.
a=input("Enter the Username :")
b=input("Enter the Password :")
c=input("Enter your Role(Admin/Manager/User):")
if a== "user1" and b== "pass1" :
        if c== "Admin" :
            print("Admin Dashboard")
        elif c== "Manager" :
            print("Team View")
        elif c== "User" : 
            print("Profile Page")
        else :
            print("Access Denied")
else :
    print("Invalid Credentials")
# Out:
# Enter the Username : user1
# Enter the Password : pass1
# Enter your Role(Admin/Manager/User): Admin
# Admin Dashboard

# %%
#Q9. Case1.
a=float(input("Enter the number : "))
sign=input("Enter the operator)
b=float(input("Enter the number : "))
c=0
if c>=0 and c>=(a+b):
      print(a + b == c)
else:
    print("Invalid")
# Out:
#   Cell In[98], line 3
#     sign=input("Enter the operator)
#                ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
#Q10.
a=int(input("Enter the Date :"))
b=int(input("Enter the Month :"))
c=int(input("Enter the Year :"))
if a>=1 and a<=31 and b>=1 and b<=12 and c in range(2000,3000) :
    ('a',/'b',/'c')
    print(('a',/'b',/'c'),"valid")
else :
    print(('a',/'b',/'c'),"invalid")
# Out:
#   Cell In[104], line 6
#     ('a',/'b',/'c')
#          ^
# SyntaxError: invalid syntax

# %%
#Q15.
password=input("Enter the password :")
if password=="Abc@1234" :
    print("Strong passwaord")
else :
    print("Weak Password")
# Out:
# Enter the password : Abc@1234
# Strong passwaord

# %%
#Q14.
a=int(input("Enter the number :"))
b=int(input("Enter the number :"))
c=int(input("Enter the number :"))
if a<

# %%
#Q12.
a=int(input("Enter the number :"))
if a%2==0 and a>=0:
    print("Only even prime")
elif a%2==0 and a<=3:
    print("Even Composite")
elif a<2:
    print("Neither Prime nor Composite")
else
• "Odd Prime" if the number is odd and prime
