# %%
print("hello world")
# Out:
# hello world

# %%
a=8
b=12
c=a+b
print("Sum =",c)
# Out:
# Sum = 20

# %%
a=input("Enter your Name :" )
b=int(input("Enter your age :" ))
c=int(input("Enter your mobile number:" ))
print(a,b,c)
# Out:
# Enter your Name : Mak
# Enter your age : 21
# Enter your mobile number: 8770387727
# Mak 21 8770387727

# %%
Age = int(input("Enter your age: ")) 
if Age >=18 :
    print("You are eligble")
else:
    print("You are not eligble")
# Out:
# Enter your age:  21
# You are eligble
