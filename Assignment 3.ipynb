# %%
#Q1
number=int(input("Enter a number :"))
if number>0 :
    print("Positive")
else:
    print("Negative")
# Out:
# Enter a number : 8
# Positive

# %%
#Q2
number=int(input("Enter a number :"))
if number%2 :
    print("Odd")
else:
    print("Even")
# Out:
# Enter a number : 9
# Odd

# %%
#Q3
marks=int(input("Enter the marks :"))
if marks>=90 :
    print("Grade A")
elif marks>=80 :
    print("Grade B")
elif marks>=70 :
    print("Grade C")
elif marks>=60:
    print("Grade D")
else :
    print("Grade E")
# Out:
# Enter the marks : -110
# Grade E

# %%
#Q4
number=int(input("Enter the number :"))
if number % 3 == 0 and number % 5 == 0:
    print("Divisible")
else :
    print("Not Divisible")
# Out:
# Enter the number : 15
# Divisible

# %%
#Q5.A
age=int(input("Enter the age :"))
if age<= 12 :
    print("Child")
elif marks<=19 :
    print("Teenager")
elif marks<=64 :
    print("Adult")
else :
    print("Senior")
# Out:
# Enter the age : 8
# Child

# %%
#Q5.B
age=int(input("Enter the age :"))
if age<= 12 :
    print("Child")
elif marks<=19 :
    print("Teenager")
elif marks<=64 :
    print("Adult")
else :
    print("Senior")
# Out:
# Enter the age : 16
# Adult

# %%
#Q6.Test Case1.
year=int(input("Enter the year :"))
if year%4==0 :
    print("Leap Year")
else :
    print("Normal Year")
# Out:
# Enter the year : 1600
# Leap Year

# %%
#Q6.Test Case2.
year=int(input("Enter the year :"))
if year%4==0 :
    print("Not a leap year")
else :
    print("Leap Year")
# Out:
# Enter the year : 1900
# Not a leap year

# %%
#Q7.
a=int(input("Enter the first number"))
b=int(input("Enter the second number"))
c=int(input("Enter the third number"))
if a>=b and a>c :
    print("Greatest out of 3: a")
elif b>=a and b>c :
    print("Greatest out of 3: b")
else :
    print("Greatest out of 3: c")
# Out:
# Enter the first number 78
# Enter the second number 56
# Enter the third number 100
# Greatest out of 3: c

# %%
#Q8.
a=int(input("Enter the first side"))
b=int(input("Enter the second side"))
c=int(input("Enter the third side"))
if a==b and b==c :
    print("Equilateral Triangle")
elif a==b or b==c or a==c :
    print("Isoceles Triangle")
else :
    print("Scalene Triangle")
# Out:
# Enter the first side 7
# Enter the second side 7
# Enter the third side 1
# Isoceles Triangle

# %%
#Q9.
year=int(input("Enter the year : "))
if year%100==0 :
    print("Century Year")
else:
    print("Normal Year")
# Out:
# Enter the year :  3000
# Century Year

# %%
# Q10.
a=int(input("Enter the first number"))
b=int(input("Enter the second number"))
c=int(input("Enter the third number"))
if a==b and c==a:
    print("Equal")
else:
    print("Not Equal")
# Out:
# Enter the first number 10
# Enter the second number 20
# Enter the third number 10
# Not Equal

# %%
#Q11.
x=float(input("Enter the number :"))
y=float(input("Enter the number :"))
if x>0 and y>0 :
    print ("First Quadrant")
elif x<0 and y>0 :
    print ("Second Quadrant")
elif x<0 and y<0 :
    print("Third Qadrant")
else :
    print("Fourth Quadrant")
# Out:
# Enter the number : 8
# Enter the number : -1
# Fourth Quadrant

# %%
#Q11.
month=int(input("Enter the Month :"))
if 3<=month and month<= 5 :
    print ("Spring")
elif 6<=month and month<= 8 :
    print ("Summer")
elif 9<=month and month<=11 :
    print("Autumn")
else :
    print("Winter")
# Out:
# Enter the Month : 7
# Summer

# %%
# Q12.
a=int(input("LOWER RANGE: "))
b=int(input("UPPER RANGE :"))
c=int(input("INPUT NUMBER :"))
if a<=c and c<=b:
    print("Yes")
else:
    print("No")
# Out:
# LOWER RANGE:  10
# UPPER RANGE : 89
# INPUT NUMBER : 77
# Yes

# %%
#Q13.
a=int(input("Enter the angle: "))
b=int(input("Enter the angle: "))
c=int(input("Enter the angle: "))
if a+b+c == 180 and a>0 and b>0 and c>0 :
    print("Triangle")
else:
    print("Not a Triangle")
# Out:
# Enter the angle:  60
# Enter the angle:  60
# Enter the angle:  60
# Triangle

# %%
#Q14.
a=int(input("Enter the Number: "))
b=int(input("Enter the Number: "))
c=input("Enter the Operator(+, -, *, /, %): ")
if c== '+' :
    print(a+b)
elif c== '-' :
    print(a-b)
elif c== '*' :
    print(a*b)
elif c== '%':
    print(a%b)
else :
    print("Invalid Operator")
# Out:
# Enter the Number:  5
# Enter the Number:  2
# Enter the Operator(+, -, *, /, %):  *
# 10

# %%
#Q15.
a=int(input("Selling Price of a product: "))
b=int(input("Cost Price of a product: "))
c=int(a-b)
if a>=b and a-b>0 :
    print("Profit is",c)
else:
    print("Loss is",c)
# Out:
# Selling Price of a product:  1500
# Cost Price of a product:  1000
# Profit is 500

# %%
#Q16.Test case 1:
week=int(input("Enter the number"))
if week==1 :
         print("Monday")
elif week==2 :
         print("Tuesday")
elif week==3 :
         print("Wednesday")
elif week==4 :
         print("Thursday")
elif week==5 :
         print("Friday")
elif week==6 :
         print("Saturday")
elif week==7 :
         print("Sunday")
else :
         print("Invalid week number. Please enter a number between 1 and 7.")
# Out:
# Enter the number 1
# Monday

# %%
#Q16.Test case 2:
week=int(input("Enter the number"))
if week==1 :
         print("Monday")
elif week==2 :
         print("Tuesday")
elif week==3 :
         print("Wednesday")
elif week==4 :
         print("Thursday")
elif week==5 :
         print("Friday")
elif week==6 :
         print("Saturday")
elif week==7 :
         print("Sunday")
else :
         print("Invalid week number. Please enter a number between 1 and 7.")
# Out:
# Enter the number 7
# Sunday

# %%
#Q.17.Test Case 1:
a=int(input("Enter the Number: "))
b=int(input("Enter the Number: "))
c=int(input("Enter the Number: "))
if a<b<c:
    print("Increasing Order")
elif a>b>c:
    print("Decreasing Order")
else:
    print("Neither increasing, nor decreasing")
# Out:
# Enter the Number:  10
# Enter the Number:  17
# Enter the Number:  20
# Increasing Order

# %%
#Q.17.Test Case 2:
a=int(input("Enter the Number: "))
b=int(input("Enter the Number: "))
c=int(input("Enter the Number: "))
if a<b<c:
    print("Increasing Order")
elif a>b>c:
    print("Decreasing Order")
else:
    print("Neither increasing, nor decreasing")
# Out:
# Enter the Number:  90
# Enter the Number:  69
# Enter the Number:  36
# Decreasing Order

# %%
#Q18.
quantity=int(input("Enter the Quantitiy purchased: "))
price= float(input("Enter the price per item: "))
total=quantity * price
if quantity>100 :
    discount = total*0.10
    total_expenses = total - discount
    print("The total expense is Rs.", total_expenses)
else:
    print("The total expense is Rs.", total)
# Out:
# Enter the Quantitiy purchased:  90
# Enter the price per item:  100
# The total expense is Rs. 9000.0

# %%
#Q19.Case 1
a=int(input("Enter the unit of electricity : "))
bill=0
total_bill=0
if a>=0 and a<=50 :
    bill = a * 0.50
elif a>=50 and a<200 :
        bill = 25+((a-50)*0.75)
elif a>=200 and a<=450:
    bill = 137.5+((a-200)*0.75)
elif a>=450 and a<=450 :
    bill = 377.5+((a-450)*0.75)
else:
    print("Invalid Unit")

total_bill=bill+(bill*0.20)
print("Total bill :",total_bill)
# Out:
# Enter the unit of electricity :  100
# Total bill : 75.0

# %%
#Q19.Case 2
a=int(input("Enter the unit of electricity : "))
bill=0
total_bill=0
if a>=0 and a<=50 :
    bill = a * 0.50
elif a>=50 and a<200 :
        bill = 25+((a-50)*0.75)
elif a>=200 and a<=450:
    bill = 137.5+((a-200)*1.20)
elif a>=450 and a<=450 :
    bill = 377.5+((a-450)*1.50)
else:
    print("Invalid Unit")

total_bill=bill+(bill*0.20)
print("Total bill :",total_bill)
# Out:
# Enter the unit of electricity :  300
# Total bill : 309.0

# %%
#Q20.Case 1
a=int(input("Enter the unit of distance covered : "))
bill=0
if a>=0 and a<=10 :
    bill = a * 11
elif a>=10 and a<100 :
        bill = 110+((a-10)*10)
elif a>=100 and a<=100 :
    bill = 1010+((a-100)*9)
else:
    print("Invalid Unit")

print("Total bill :",bill)
# Out:
# Enter the unit of distance covered :  50
# Total bill : 510

# %%
#Q20.Case 2
a=int(input("Enter the unit of distance covered : "))
bill=0
if a>=0 and a<=10 :
    bill = a * 11
elif a>=10 and a<100 :
        bill = 110+((a-10)*10)
elif a>=100 and a<=100 :
    bill = 1010+((a-100)*9)
else:
    print("Invalid Unit")

print("Total bill :",bill)
# Out:
# Enter the unit of distance covered :  100
# Total bill : 1010
