# %%
#Q1
a=input("Enter you Name : ")
print(a)
# Out:
# Enter you Name :  MAK DUBEY
# MAK DUBEY

# %%
#Q2
a=int(input("Enter your age : "))
b=10
c=a+b
print(c)
# Out:
# Enter your age :  12
# 22

# %%
#Q3
name=input("Enter your Name : ")
age=int(input("Enter your Age : "))
height=float(input("Enter your Height : "))
print("My name is", name,"my age is", age, "and height is", height)
# Out:
# Enter your Name :  Alice
# Enter your Age :  10
# Enter your Height :  3.5
# My name is Alice my age is 10 and height is 3.5

# %%
#Q4
a=float(input('Enter price : Rs. '))
print(a)
# Out:
# Enter price : Rs.  125
# 125.0

# %%
#Q5
a=int(input("Enter the number"))
b=int(input("Enter the number"))
c=a+b
print("Sum =",c)
# Out:
# Enter the number 3
# Enter the number 4
# Sum = 7

# %%
#Q6
Age=int(input("Enter your Age"))
print("My age is", Age)
# Out:
# Enter your Age 21
# My age is 21

# %%
#Q7.
Radius=float(input("Enter the Radius"))
Area=(3.14 * Radius * Radius)
print("The area of the circle is :", Area)
# Out:
# Enter the Radius 7
# The area of the circle is : 153.86

# %%
#Q8
a=int(input("Enter the number"))
b=(a)
print(b)
# Out:
# Enter the number 234
# 234

# %%
#Q9
Height=float(input("Enter your Height"))
Convert=(0.3048 * Height)
print(Convert, "feet")
# Out:
# Enter your Height 500
# 152.4

# %%
#Q10
a=int(input("Enter the first integer"))
b=int(input("Enter the second integer"))
c=float(input("Enter the third integer"))
print(a, b, c)
# Out:
# Enter the first integer 5
# Enter the second integer 10
# Enter the third integer 3.14
# 5 10 3.14

# %%
#QB1
Number=int(input("Enter the Number :"))
if Number >=0 :
    print("Positive")
else:
    print("Negative")
# Out:
# Enter the Number : 8
# Positive

# %%
#QB2
a=int(input("Enter the number"))
b=int(input("Enter the number"))
if a+b > 10 :
    print("Greater")
else:
    print("Less")
# Out:
# Enter the number 5
# Enter the number 3
# Less

# %%
#QB3
a=int(input("Enter the number"))
b=int(input("Enter the number"))
if a > b :
    print("Greater")
else:
    print("Less")
# Out:
# Enter the number 98
# Enter the number 89
# Greater

# %%
# QB4
number=int(input("Enter the number"))
if number%5 == 0:
    print("Divisble")
else:
    print("Not Divisble")
# Out:
# Enter the number 90
# Divisble

# %%
#QB5
a=int(input("Enter the Angle :"))
b=int(input("Enter the Angle :"))
c=int(input("Enter the Angle :"))
d=int(input("Enter the Angle :"))
if (a+b+c+d) == 360:
    print("Quadrilateral")
else:
    print("Not a Quadrilateral")
# Out:
# Enter the Number : 35
# Enter the Number : 62
# Enter the Number : 35
# Enter the Number : 26
# Not a Quadrilateral
